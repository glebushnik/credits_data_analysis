# %%
import pandas as pd
import re
import numpy as np

# Загрузка данных из CSV-файла в DataFrame
df = pd.read_csv('Dannye_o_kreditnoy_istorii_klientov.csv')

# %%
#смотрим первые записи, чтобы понять, что есть в датасете
df.head()
# Out:
#   checking_status  duration                  credit_history  \
# 0              <0       6.0  critical/other existing credit
# 1        0<=X<200      48.0                   existing paid
# 2     no checking      12.0  critical/other existing credit
# 3              <0      42.0                   existing paid
# 4              <0      24.0              delayed previously
#
#                purpose  credit_amount    savings_status employment  \
# 0             radio/tv         1169.0  no known savings        >=7
# 1             radio/tv         5951.0              <100     1<=X<4
# 2            education         2096.0              <100     4<=X<7
# 3  furniture/equipment         7882.0              <100     4<=X<7
# 4              new car         4870.0              <100     1<=X<4
#
#    installment_commitment     personal_status other_parties  residence_since  \
# 0                     4.0         male single           NaN              4.0
# ...

# %%
#заметили, что в other_parties есть значения none, проверяем все значения
df.other_parties.unique()
# Out:
# array(['<0', '0<=X<200', 'no checking', '>=200'], dtype=object)

# %%
#заменяем все значения none на NULL
df.other_parties = df.other_parties.replace('none', np.nan)

# %%
#смотрим, сколько в сете other_parties значений NULL
df[df['other_parties'].isnull() == True]
# Out:
#     checking_status  duration                  credit_history  \
# 0                <0       6.0  critical/other existing credit
# 1          0<=X<200      48.0                   existing paid
# 2       no checking      12.0  critical/other existing credit
# 4                <0      24.0              delayed previously
# 5       no checking      36.0                   existing paid
# ..              ...       ...                             ...
# 995     no checking      12.0                   existing paid
# 996              <0      30.0                   existing paid
# 997     no checking      12.0                   existing paid
# 998              <0      45.0                   existing paid
# 999        0<=X<200      45.0  critical/other existing credit
#
#                  purpose  credit_amount    savings_status  employment  \
# 0               radio/tv         1169.0  no known savings         >=7
# 1               radio/tv         5951.0              <100      1<=X<4
# ...

# %%
#заметили, что в savings_status есть значения no known savings, проверяем все значения
df.savings_status.unique()
# Out:
# array(['no known savings', '<100', '500<=X<1000', '>=1000', '100<=X<500'],
#       dtype=object)

# %%
#заменяем все значения 'no known savings' на NULL
df.savings_status = df.savings_status.replace('no known savings', np.nan)

# %%
df[df['savings_status'].isnull() == True]
# Out:
#     checking_status  duration                  credit_history  \
# 0                <0       6.0  critical/other existing credit
# 5       no checking      36.0                   existing paid
# 16      no checking      24.0  critical/other existing credit
# 17               <0      30.0             no credits/all paid
# 24      no checking      10.0  critical/other existing credit
# ..              ...       ...                             ...
# 968     no checking      42.0                   existing paid
# 977        0<=X<200      18.0              delayed previously
# 990     no checking      12.0  critical/other existing credit
# 992              <0      18.0                   existing paid
# 994     no checking      12.0                   existing paid
#
#                  purpose  credit_amount savings_status employment  \
# 0               radio/tv         1169.0            NaN        >=7
# 5              education         9055.0            NaN     1<=X<4
# ...

# %%
#в этом сете все ок, нет null значений
df.checking_status.unique()
# Out:
# array(['<0', '0<=X<200', 'no checking', '>=200'], dtype=object)

# %%
#в этом сете все ок, нет null значений
df.duration.unique()
# Out:
# array([ 6., 48., 12., 42., 24., 36., 30., 15.,  9., 10.,  7., 60., 18.,
#        45., 11., 27.,  8., 54., 20., 14., 33., 21., 16.,  4., 47., 13.,
#        22., 39., 28.,  5., 26., 72., 40.])

# %%
#в этом сете все ок, нет null значений
df.credit_history.unique()
# Out:
# array(['critical/other existing credit', 'existing paid',
#        'delayed previously', 'no credits/all paid', 'all paid'],
#       dtype=object)

# %%
#в этом сете все ок, нет null значений
df.purpose.unique()
# Out:
# array(['radio/tv', 'education', 'furniture/equipment', 'new car',
#        'used car', 'business', 'domestic appliance', 'repairs', 'other',
#        'retraining'], dtype=object)

# %%
#в этом сете все ок, нет null значений
df.credit_amount.unique()
# Out:
# array([ 1169.,  5951.,  2096.,  7882.,  4870.,  9055.,  2835.,  6948.,
#         3059.,  5234.,  1295.,  4308.,  1567.,  1199.,  1403.,  1282.,
#         2424.,  8072., 12579.,  3430.,  2134.,  2647.,  2241.,  1804.,
#         2069.,  1374.,   426.,   409.,  2415.,  6836.,  1913.,  4020.,
#         5866.,  1264.,  1474.,  4746.,  6110.,  2100.,  1225.,   458.,
#         2333.,  1158.,  6204.,  6187.,  6143.,  1393.,  2299.,  1352.,
#         7228.,  2073.,  5965.,  1262.,  3378.,  2225.,   783.,  6468.,
#         9566.,  1961.,  6229.,  1391.,  1537.,  1953., 14421.,  3181.,
#         5190.,  2171.,  1007.,  1819.,  2394.,  8133.,   730.,  1164.,
#         5954.,  1977.,  1526.,  3965.,  4771.,  9436.,  3832.,  5943.,
#         1213.,  1568.,  1755.,  2315.,  1412., 12612.,  2249.,  1108.,
#          618.,  1409.,   797.,  3617.,  1318., 15945.,  2012.,  2622.,
#         2337.,  7057.,  1469.,  2323.,   932.,  1919.,  2445., 11938.,
# ...

# %%
#в этом сете все ок, нет null значений
df.employment.unique()
# Out:
# array(['>=7', '1<=X<4', '4<=X<7', 'unemployed', '<1'], dtype=object)

# %%
#в этом сете все ок, нет null значений
df.installment_commitment.unique()
# Out:
# array([4., 2., 3., 1.])

# %%
#в этом сете все ок, нет null значений
df.personal_status.unique()
# Out:
# array(['male single', 'female div/dep/mar', 'male div/sep',
#        'male mar/wid'], dtype=object)

# %%
#в этом сете все ок, нет null значений
df.residence_since.unique()
# Out:
# array([4., 2., 3., 1.])

# %%
#смотрим уникальные значения в сете property_magnitude
df.property_magnitude.unique()
# Out:
# array(['real estate', 'life insurance', 'no known property', 'car'],
#       dtype=object)

# %%
#заменяем все значения no known property на NULL
df.property_magnitude = df.property_magnitude.replace('no known property', np.nan)

# %%
df[df['property_magnitude'].isnull() == True]
# Out:
#     checking_status  duration                  credit_history    purpose  \
# 4                <0      24.0              delayed previously    new car
# 5       no checking      36.0                   existing paid  education
# 18         0<=X<200      24.0                   existing paid   used car
# 29               <0      60.0              delayed previously   business
# 33      no checking      12.0  critical/other existing credit   business
# ..              ...       ...                             ...        ...
# 962     no checking      15.0                   existing paid    new car
# 972              <0      24.0                        all paid    new car
# 973              <0      60.0                   existing paid   business
# 988              <0      24.0                   existing paid   used car
# 998              <0      45.0                   existing paid   radio/tv
#
#      credit_amount savings_status  employment  installment_commitment  \
# ...

# %%
#в этом сете все ок, нет null значений
df.age.unique()
# Out:
# array([67., 22., 49., 45., 53., 35., 61., 28., 25., 24., 60., 32., 44.,
#        31., 48., 26., 36., 39., 42., 34., 63., 27., 30., 57., 33., 37.,
#        58., 23., 29., 52., 50., 46., 51., 41., 40., 66., 47., 56., 54.,
#        20., 21., 38., 70., 65., 74., 68., 43., 55., 64., 75., 19., 62.,
#        59.])

# %%
#смотрим уникальные значения other_payment_plans
df.other_payment_plans.unique()
# Out:
# array(['none', 'bank', 'stores'], dtype=object)

# %%
#заменяем все none значения на NULL
df.other_payment_plans = df.other_payment_plans.replace('none', np.nan)

# %%
df[df['other_payment_plans'].isnull() == True]
# Out:
#     checking_status  duration                  credit_history  \
# 0                <0       6.0  critical/other existing credit
# 1          0<=X<200      48.0                   existing paid
# 2       no checking      12.0  critical/other existing credit
# 3                <0      42.0                   existing paid
# 4                <0      24.0              delayed previously
# ..              ...       ...                             ...
# 995     no checking      12.0                   existing paid
# 996              <0      30.0                   existing paid
# 997     no checking      12.0                   existing paid
# 998              <0      45.0                   existing paid
# 999        0<=X<200      45.0  critical/other existing credit
#
#                  purpose  credit_amount savings_status  employment  \
# 0               radio/tv         1169.0            NaN         >=7
# 1               radio/tv         5951.0           <100      1<=X<4
# ...

# %%
df.housing.unique()
# Out:
# array(['own', 'for free', 'rent'], dtype=object)

# %%
df.existing_credits.unique()
# Out:
# array([2., 1., 3., 4.])

# %%
df.job.unique()
# Out:
# array(['skilled', 'unskilled resident', 'high qualif/self emp/mgmt',
#        'unemp/unskilled non res'], dtype=object)

# %%
df.num_dependents.unique()
# Out:
# array([1., 2.])

# %%
df.own_telephone.unique()
# Out:
# array(['yes', 'none'], dtype=object)

# %%
df.own_telephone = df.own_telephone.replace('none', np.nan)

# %%
df.foreign_worker.unique()
# Out:
# array(['yes', 'no'], dtype=object)

# %%
#смотрим типы данных
#нужно привести к int сеты: duration, credit_amount, installment_commitment, residence_since, age, existing_credits, num_dependents
df.dtypes
# Out:
# checking_status            object
# duration                  float64
# credit_history             object
# purpose                    object
# credit_amount             float64
# savings_status             object
# employment                 object
# installment_commitment    float64
# personal_status            object
# other_parties              object
# residence_since           float64
# property_magnitude         object
# age                       float64
# other_payment_plans        object
# housing                    object
# existing_credits          float64
# job                        object
# num_dependents            float64
# own_telephone              object
# foreign_worker             object
# class                      object
# dtype: object

# %%
#cмотрим таблицу с новыми значениями
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   checking_status         1000 non-null   object
#  1   duration                1000 non-null   float64
#  2   credit_history          1000 non-null   object
#  3   purpose                 1000 non-null   object
#  4   credit_amount           1000 non-null   float64
#  5   savings_status          817 non-null    object
#  6   employment              1000 non-null   object
#  7   installment_commitment  1000 non-null   float64
#  8   personal_status         1000 non-null   object
#  9   other_parties           93 non-null     object
#  10  residence_since         1000 non-null   float64
#  11  property_magnitude      846 non-null    object
#  12  age                     1000 non-null   float64
#  13  other_payment_plans     186 non-null    object
# ...
